# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/ds_test_s1.csv')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a0aab7da733> in <module>()
# ----> 1 data = pd.read_csv('/ds_test_s1.csv')
#       2 data
#
# NameError: name 'pd' is not defined

# %%
ds_students = data[['First name','Last name','Percentage']]
df = ds_students.sort_values(by=['Percentage'],ascending=False).reset_index(drop=True).dropna()
df
# Out:
#        First name        Last name Percentage
# 0         Umidbek  Maxammadsoliyev      93.3%
# 1          Olimov           Behzod      92.5%
# 2      First Name        Last Name      90.4%
# 3           Steve          Johnson      88.3%
# 4          Alixan      Minturganov      88.3%
# 5           Abbos          Rasulov      86.3%
# 6         Abdulla        Abduqulov        81%
# 7           Zafar         Davlatov      80.8%
# 8   Muhammad Amin     Mahmutaliyev      80.4%
# 9           Maruf        Ibragimov      80.4%
# 10          Jasur        Abdibayev      77.9%
# 11       Dilmurod          Axmadov      74.6%
# 12         Azamat          İlyosov      73.9%
# 13   Mukhammadali          Nizomov      73.8%
# 14       Qalqonov           Behruz      70.2%
# 15        Humoyun          Qosimov      68.1%
# 16      abduhalil      abdumominov      67.1%
# 17    Shaxobiddin       Muhiddinov        61%
# 18       Nosirjon         Davronov      60.4%
# ...

# %%
import plotly.express as px
fig = px.bar(df, x='First name', y='Percentage',
            color='Percentage',
            height=600)
fig.show()
# df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
# df.loc[df['Last name'] < 2.e6, 'First name'] = 'Other countries'
# fig = px.pie(df, values='Last name', names='First name', title='Percentage')
# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install Dash

# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px

# %%
# fig = px.pie(df, values='Percentage', names='First name', title='Percentage')
# fig.show()

# %%
app = Dash(__name__)

app.layout = html.Div([
    html.H4('Analysis of Iris data using scatter matrix'),
    dcc.Dropdown(
        id="dropdown",
        options=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'],
        value=['sepal_length', 'sepal_width'],
        multi=True
    ),
    dcc.Graph(id="graph"),
])


@app.callback(
    Output("graph", "figure"), 
    Input("dropdown", "value"))
def update_bar_chart(dims):
    data = pd.read_csv('/content/ds_test_s1 (1).csv')
    ds_students = data[['First name','Last name','Percentage']]
    df = ds_students.sort_values(by=['Percentage'],ascending=False).reset_index(drop=True).dropna()
    fig = px.bar(df, x='Last name', y='Percentage',
            color='Percentage',
            height=600)
    return fig


app.run_server(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-44-6014fa1f7f27> in <module>()
#      26
#      27
# ---> 28 app.run_server(debug=True)
#
# /usr/local/lib/python3.7/dist-packages/dash/dash.py in run_server(self, host, port, proxy, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
# ...
